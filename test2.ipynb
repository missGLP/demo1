# %% [markdown]
# # Description
# this is a description

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#                                                   摘要     事务密钥   事务ID 事务类型  \
# 0                关闭体温检测时，库中真人检测会出现“验证成功，非活体，不通过”的情况。  RNIB-85  10110   缺陷
# 1                       刷脸设置页面，活体检测开关默认是关闭状态，应该是开启状态  RNIB-75  10100   缺陷
# 2  网络管理-网络设置-有线网络，关闭自动获取IP地址选项时，输入IP地址等信息或者不输入，点击...  RNIB-71  10096   缺陷
# 3  在APP内，有弹出输入框的地方，比如进入设置菜单时的密码输入页、刷脸设置页面修改人脸对比阈值...  RNIB-63  10088   缺陷
# 4         设备信息页面，编辑设备名称时，会弹出输入法，此时点击刷脸，会跳到刷脸键，输入法未消失  RNIB-62  10087   缺陷
#
#     状态   项目键         项目名称      项目类型  项目负责人  项目描述  ...  \
# 0  已完成  RNIB  触摸屏人脸识别测温门禁  software  admin   NaN  ...
# 1  已完成  RNIB  触摸屏人脸识别测温门禁  software  admin   NaN  ...
# 2  已完成  RNIB  触摸屏人脸识别测温门禁  software  admin   NaN  ...
# 3  已完成  RNIB  触摸屏人脸识别测温门禁  software  admin   NaN  ...
# 4  已完成  RNIB  触摸屏人脸识别测温门禁  software  admin   NaN  ...
#
#   自定义字段 (Story point estimate) 自定义字段 (Target end) 自定义字段 (Target start)  \
# 0                          NaN                NaN                  NaN
# ...
